# %% [markdown]
# # Imports

# %%
import h5py
import os
import re
import zipfile
import pickle as pkl

from collections import defaultdict

# %%
file_path = "./bif.hdf5"
links_path = "./bifurcating_list.txt"
tsv_path = "./bif_drive.tsv"
output_dir = "./bif"
dataset_name = "bif"

# file_path = "./single.hdf5"
# links_path = "./single_list.txt"
# tsv_path = "./single_drive.tsv"
# output_dir = "./single"
# dataset_name = "single"
sample_exact_number = 2000

# %% [markdown]
# # Check missing samples

# %%
missing = False

with h5py.File(file_path, 'a') as file:
    current_len = len(file)
    print(f"[{dataset_name}] Dataset len: ",len(file))
    sample_names = [name for name in file.keys() if name.startswith('sample_')]

numbers = [re.search(r'_\d+', s).group()[1:] for s in sample_names]
for n in range(len(numbers)):
    counter = f'{n:04d}'
    if numbers[n] != counter:
        print(f"[{dataset_name}] Missing sample number: ", counter)
        missing_number = counter
        missing = True
        break

if not missing:
    print(f"[{dataset_name}] All samples are present")
# Out:
# [single] Dataset len:  2000
# [single] All samples are present

# %% [markdown]
# # Complete dataset

# %%
if current_len < sample_exact_number:
    campione_origine = "sample_1000"   
    campione_destinazione = "sample_" + missing_number

    # Apri il file di origine in modalità lettura
    with h5py.File(file_path, 'a') as file:
        # Verifica se il campione di origine esiste
        if campione_origine not in file:
            error_string = f"Sample '{campione_origine}' doesn't exists"
            print(f"[{dataset_name}] " + error_string)
          
        else:
            file.copy(campione_origine, file, name = campione_destinazione)
            print(f"[{dataset_name}] New dataset len: ",len(file))
else:
    print(f"[{dataset_name}] All samples are present")
# Out:
# [single] All samples are present

# %% [markdown]
# # Split dataset

# %%
num_files = 100

# Apri il file HDF5 in modalità lettura
with h5py.File(file_path, 'r') as file:
    # Ottieni la lista dei nomi dei campioni
    sample_names = [name for name in file.keys()]

    # Calcola il numero di campioni per file
    samples_per_file = len(sample_names) // num_files
    remainder = len(sample_names) % num_files

    # Indice per tenere traccia in cui ci si trova nella lista dei campioni
    index = 0

    # Per ogni file, crea un nuovo file HDF5 e copia i campioni
    for i in range(num_files):
        # Calcola il numero di campioni da copiare in questo file
        samples_in_this_file = samples_per_file + int(i < remainder)

        # Crea il nuovo file HDF5
        output_file = output_dir + "/" + dataset_name + f"_{i + 1}.hdf5"
        with h5py.File(output_file, 'w') as output_file:
            # Copia i campioni nel nuovo file
            for j in range(samples_in_this_file):
                sample_name = sample_names[index]
                file.copy(sample_name, output_file)

                # Incrementa l'indice per il prossimo campione
                index += 1

print(f"[{dataset_name}] Data divided in {num_files} files hdf5")
# Out:
# [single] Data divided in 100 files hdf5

# %% [markdown]
# # Check results

# %%
def exctract_key(stringa):
    # Estrai il numero dalla stringa
    return int(stringa.split('_')[1].split('.')[0])

files = [
    os.path.join(root, file) for root, 
    dirs, files in os.walk(output_dir) for file in files
]

# Ordina la lista utilizzando la funzione di chiave personalizzata
sorted_files = sorted(files, key = exctract_key)

checksum = 0

for file in sorted_files:
    filename = file.split("\\")[-1]
    with h5py.File(file, 'r') as data_patch:
        data_len = len(data_patch)
        checksum += data_len
        first_elem = list(data_patch.keys())[0]
        last_elem = list(data_patch.keys())[-1]
        print(f"[{filename}] Samples: ",data_len)
        print(f"[{filename}] First sample",first_elem)
        print(f"[{filename}] First sample",last_elem)

if checksum == 2000:
    print(f"[{dataset_name}] Splitted successfully")
else:
    print(f"[{dataset_name}] Some error occours during splitting")
# Out:
# [single_1.hdf5] Samples:  20
# [single_1.hdf5] First sample sample_0000
# [single_1.hdf5] First sample sample_0019
# [single_2.hdf5] Samples:  20
# [single_2.hdf5] First sample sample_0020
# [single_2.hdf5] First sample sample_0039
# [single_3.hdf5] Samples:  20
# [single_3.hdf5] First sample sample_0040
# [single_3.hdf5] First sample sample_0059
# [single_4.hdf5] Samples:  20
# [single_4.hdf5] First sample sample_0060
# [single_4.hdf5] First sample sample_0079
# [single_5.hdf5] Samples:  20
# [single_5.hdf5] First sample sample_0080
# [single_5.hdf5] First sample sample_0099
# [single_6.hdf5] Samples:  20
# [single_6.hdf5] First sample sample_0100
# [single_6.hdf5] First sample sample_0119
# [single_7.hdf5] Samples:  20
# [single_7.hdf5] First sample sample_0120
# [single_7.hdf5] First sample sample_0139
# [single_8.hdf5] Samples:  20
# [single_8.hdf5] First sample sample_0140
# [single_8.hdf5] First sample sample_0159
# [single_9.hdf5] Samples:  20
# [single_9.hdf5] First sample sample_0160
# [single_9.hdf5] First sample sample_0179
# [single_10.hdf5] Samples:  20
# [single_10.hdf5] First sample sample_0180
# [single_10.hdf5] First sample sample_0199
# [single_11.hdf5] Samples:  20
# [single_11.hdf5] First sample sample_0200
# [single_11.hdf5] First sample sample_0219
# [single_12.hdf5] Samples:  20
# [single_12.hdf5] First sample sample_0220
# [single_12.hdf5] First sample sample_0239
# [single_13.hdf5] Samples:  20
# [single_13.hdf5] First sample sample_0240
# [single_13.hdf5] First sample sample_0259
# [single_14.hdf5] Samples:  20
# [single_14.hdf5] First sample sample_0260
# [single_14.hdf5] First sample sample_0279
# [single_15.hdf5] Samples:  20
# [single_15.hdf5] First sample sample_0280
# [single_15.hdf5] First sample sample_0299
# [single_16.hdf5] Samples:  20
# [single_16.hdf5] First sample sample_0300
# [single_16.hdf5] First sample sample_0319
# [single_17.hdf5] Samples:  20
# [single_17.hdf5] First sample sample_0320
# [single_17.hdf5] First sample sample_0339
# [single_18.hdf5] Samples:  20
# [single_18.hdf5] First sample sample_0340
# [single_18.hdf5] First sample sample_0359
# [single_19.hdf5] Samples:  20
# [single_19.hdf5] First sample sample_0360
# [single_19.hdf5] First sample sample_0379
# [single_20.hdf5] Samples:  20
# [single_20.hdf5] First sample sample_0380
# [single_20.hdf5] First sample sample_0399
# [single_21.hdf5] Samples:  20
# [single_21.hdf5] First sample sample_0400
# [single_21.hdf5] First sample sample_0419
# [single_22.hdf5] Samples:  20
# [single_22.hdf5] First sample sample_0420
# [single_22.hdf5] First sample sample_0439
# [single_23.hdf5] Samples:  20
# [single_23.hdf5] First sample sample_0440
# [single_23.hdf5] First sample sample_0459
# [single_24.hdf5] Samples:  20
# [single_24.hdf5] First sample sample_0460
# [single_24.hdf5] First sample sample_0479
# [single_25.hdf5] Samples:  20
# [single_25.hdf5] First sample sample_0480
# [single_25.hdf5] First sample sample_0499
# [single_26.hdf5] Samples:  20
# [single_26.hdf5] First sample sample_0500
# [single_26.hdf5] First sample sample_0519
# [single_27.hdf5] Samples:  20
# [single_27.hdf5] First sample sample_0520
# [single_27.hdf5] First sample sample_0539
# [single_28.hdf5] Samples:  20
# [single_28.hdf5] First sample sample_0540
# [single_28.hdf5] First sample sample_0559
# [single_29.hdf5] Samples:  20
# [single_29.hdf5] First sample sample_0560
# [single_29.hdf5] First sample sample_0579
# [single_30.hdf5] Samples:  20
# [single_30.hdf5] First sample sample_0580
# [single_30.hdf5] First sample sample_0599
# [single_31.hdf5] Samples:  20
# [single_31.hdf5] First sample sample_0600
# [single_31.hdf5] First sample sample_0619
# [single_32.hdf5] Samples:  20
# [single_32.hdf5] First sample sample_0620
# [single_32.hdf5] First sample sample_0639
# [single_33.hdf5] Samples:  20
# [single_33.hdf5] First sample sample_0640
# [single_33.hdf5] First sample sample_0659
# [single_34.hdf5] Samples:  20
# [single_34.hdf5] First sample sample_0660
# [single_34.hdf5] First sample sample_0679
# [single_35.hdf5] Samples:  20
# [single_35.hdf5] First sample sample_0680
# [single_35.hdf5] First sample sample_0699
# [single_36.hdf5] Samples:  20
# [single_36.hdf5] First sample sample_0700
# [single_36.hdf5] First sample sample_0719
# [single_37.hdf5] Samples:  20
# [single_37.hdf5] First sample sample_0720
# [single_37.hdf5] First sample sample_0739
# [single_38.hdf5] Samples:  20
# [single_38.hdf5] First sample sample_0740
# [single_38.hdf5] First sample sample_0759
# [single_39.hdf5] Samples:  20
# [single_39.hdf5] First sample sample_0760
# [single_39.hdf5] First sample sample_0779
# [single_40.hdf5] Samples:  20
# [single_40.hdf5] First sample sample_0780
# [single_40.hdf5] First sample sample_0799
# [single_41.hdf5] Samples:  20
# [single_41.hdf5] First sample sample_0800
# [single_41.hdf5] First sample sample_0819
# [single_42.hdf5] Samples:  20
# [single_42.hdf5] First sample sample_0820
# [single_42.hdf5] First sample sample_0839
# [single_43.hdf5] Samples:  20
# [single_43.hdf5] First sample sample_0840
# [single_43.hdf5] First sample sample_0859
# [single_44.hdf5] Samples:  20
# [single_44.hdf5] First sample sample_0860
# [single_44.hdf5] First sample sample_0879
# [single_45.hdf5] Samples:  20
# [single_45.hdf5] First sample sample_0880
# [single_45.hdf5] First sample sample_0899
# [single_46.hdf5] Samples:  20
# [single_46.hdf5] First sample sample_0900
# [single_46.hdf5] First sample sample_0919
# [single_47.hdf5] Samples:  20
# [single_47.hdf5] First sample sample_0920
# [single_47.hdf5] First sample sample_0939
# [single_48.hdf5] Samples:  20
# [single_48.hdf5] First sample sample_0940
# [single_48.hdf5] First sample sample_0959
# [single_49.hdf5] Samples:  20
# [single_49.hdf5] First sample sample_0960
# [single_49.hdf5] First sample sample_0979
# [single_50.hdf5] Samples:  20
# [single_50.hdf5] First sample sample_0980
# [single_50.hdf5] First sample sample_0999
# [single_51.hdf5] Samples:  20
# [single_51.hdf5] First sample sample_1000
# [single_51.hdf5] First sample sample_1019
# [single_52.hdf5] Samples:  20
# [single_52.hdf5] First sample sample_1020
# [single_52.hdf5] First sample sample_1039
# [single_53.hdf5] Samples:  20
# [single_53.hdf5] First sample sample_1040
# [single_53.hdf5] First sample sample_1059
# [single_54.hdf5] Samples:  20
# [single_54.hdf5] First sample sample_1060
# [single_54.hdf5] First sample sample_1079
# [single_55.hdf5] Samples:  20
# [single_55.hdf5] First sample sample_1080
# [single_55.hdf5] First sample sample_1099
# [single_56.hdf5] Samples:  20
# [single_56.hdf5] First sample sample_1100
# [single_56.hdf5] First sample sample_1119
# [single_57.hdf5] Samples:  20
# [single_57.hdf5] First sample sample_1120
# [single_57.hdf5] First sample sample_1139
# [single_58.hdf5] Samples:  20
# [single_58.hdf5] First sample sample_1140
# [single_58.hdf5] First sample sample_1159
# [single_59.hdf5] Samples:  20
# [single_59.hdf5] First sample sample_1160
# [single_59.hdf5] First sample sample_1179
# [single_60.hdf5] Samples:  20
# [single_60.hdf5] First sample sample_1180
# [single_60.hdf5] First sample sample_1199
# [single_61.hdf5] Samples:  20
# [single_61.hdf5] First sample sample_1200
# [single_61.hdf5] First sample sample_1219
# [single_62.hdf5] Samples:  20
# [single_62.hdf5] First sample sample_1220
# [single_62.hdf5] First sample sample_1239
# [single_63.hdf5] Samples:  20
# [single_63.hdf5] First sample sample_1240
# [single_63.hdf5] First sample sample_1259
# [single_64.hdf5] Samples:  20
# [single_64.hdf5] First sample sample_1260
# [single_64.hdf5] First sample sample_1279
# [single_65.hdf5] Samples:  20
# [single_65.hdf5] First sample sample_1280
# [single_65.hdf5] First sample sample_1299
# [single_66.hdf5] Samples:  20
# [single_66.hdf5] First sample sample_1300
# [single_66.hdf5] First sample sample_1319
# [single_67.hdf5] Samples:  20
# [single_67.hdf5] First sample sample_1320
# [single_67.hdf5] First sample sample_1339
# [single_68.hdf5] Samples:  20
# [single_68.hdf5] First sample sample_1340
# [single_68.hdf5] First sample sample_1359
# [single_69.hdf5] Samples:  20
# [single_69.hdf5] First sample sample_1360
# [single_69.hdf5] First sample sample_1379
# [single_70.hdf5] Samples:  20
# [single_70.hdf5] First sample sample_1380
# [single_70.hdf5] First sample sample_1399
# [single_71.hdf5] Samples:  20
# [single_71.hdf5] First sample sample_1400
# [single_71.hdf5] First sample sample_1419
# [single_72.hdf5] Samples:  20
# [single_72.hdf5] First sample sample_1420
# [single_72.hdf5] First sample sample_1439
# [single_73.hdf5] Samples:  20
# [single_73.hdf5] First sample sample_1440
# [single_73.hdf5] First sample sample_1459
# [single_74.hdf5] Samples:  20
# [single_74.hdf5] First sample sample_1460
# [single_74.hdf5] First sample sample_1479
# [single_75.hdf5] Samples:  20
# [single_75.hdf5] First sample sample_1480
# [single_75.hdf5] First sample sample_1499
# [single_76.hdf5] Samples:  20
# [single_76.hdf5] First sample sample_1500
# [single_76.hdf5] First sample sample_1519
# [single_77.hdf5] Samples:  20
# [single_77.hdf5] First sample sample_1520
# [single_77.hdf5] First sample sample_1539
# [single_78.hdf5] Samples:  20
# [single_78.hdf5] First sample sample_1540
# [single_78.hdf5] First sample sample_1559
# [single_79.hdf5] Samples:  20
# [single_79.hdf5] First sample sample_1560
# [single_79.hdf5] First sample sample_1579
# [single_80.hdf5] Samples:  20
# [single_80.hdf5] First sample sample_1580
# [single_80.hdf5] First sample sample_1599
# [single_81.hdf5] Samples:  20
# [single_81.hdf5] First sample sample_1600
# [single_81.hdf5] First sample sample_1619
# [single_82.hdf5] Samples:  20
# [single_82.hdf5] First sample sample_1620
# [single_82.hdf5] First sample sample_1639
# [single_83.hdf5] Samples:  20
# [single_83.hdf5] First sample sample_1640
# [single_83.hdf5] First sample sample_1659
# [single_84.hdf5] Samples:  20
# [single_84.hdf5] First sample sample_1660
# [single_84.hdf5] First sample sample_1679
# [single_85.hdf5] Samples:  20
# [single_85.hdf5] First sample sample_1680
# [single_85.hdf5] First sample sample_1699
# [single_86.hdf5] Samples:  20
# [single_86.hdf5] First sample sample_1700
# [single_86.hdf5] First sample sample_1719
# [single_87.hdf5] Samples:  20
# [single_87.hdf5] First sample sample_1720
# [single_87.hdf5] First sample sample_1739
# [single_88.hdf5] Samples:  20
# [single_88.hdf5] First sample sample_1740
# [single_88.hdf5] First sample sample_1759
# [single_89.hdf5] Samples:  20
# [single_89.hdf5] First sample sample_1760
# [single_89.hdf5] First sample sample_1779
# [single_90.hdf5] Samples:  20
# [single_90.hdf5] First sample sample_1780
# [single_90.hdf5] First sample sample_1799
# [single_91.hdf5] Samples:  20
# [single_91.hdf5] First sample sample_1800
# [single_91.hdf5] First sample sample_1819
# [single_92.hdf5] Samples:  20
# [single_92.hdf5] First sample sample_1820
# [single_92.hdf5] First sample sample_1839
# [single_93.hdf5] Samples:  20
# [single_93.hdf5] First sample sample_1840
# [single_93.hdf5] First sample sample_1859
# [single_94.hdf5] Samples:  20
# [single_94.hdf5] First sample sample_1860
# [single_94.hdf5] First sample sample_1879
# [single_95.hdf5] Samples:  20
# [single_95.hdf5] First sample sample_1880
# [single_95.hdf5] First sample sample_1899
# [single_96.hdf5] Samples:  20
# [single_96.hdf5] First sample sample_1900
# [single_96.hdf5] First sample sample_1919
# [single_97.hdf5] Samples:  20
# [single_97.hdf5] First sample sample_1920
# [single_97.hdf5] First sample sample_1939
# [single_98.hdf5] Samples:  20
# [single_98.hdf5] First sample sample_1940
# [single_98.hdf5] First sample sample_1959
# [single_99.hdf5] Samples:  20
# [single_99.hdf5] First sample sample_1960
# [single_99.hdf5] First sample sample_1979
# [single_100.hdf5] Samples:  20
# [single_100.hdf5] First sample sample_1980
# [single_100.hdf5] First sample sample_1999
# [single] Splitted successfully

# %% [markdown]
# # Save zip

# %%
files_hdf5 = [
    file for file in os.listdir(output_dir) if file.endswith('.hdf5')
]
for file_hdf5 in files_hdf5:
    # Costruisci il percorso completo del file HDF5
    percorso_file_hdf5 = output_dir + "/" + file_hdf5

    # Costruisci il percorso completo per il file zip
    percorso_file_zip = output_dir + f"/{os.path.splitext(file_hdf5)[0]}.zip"

    # Crea il file zip e aggiungi il file HDF5
    with zipfile.ZipFile(percorso_file_zip, 'w') as zipf:
        zipf.write(percorso_file_hdf5, file_hdf5)

# %% [markdown]
# # Clear data

# %%
files = [
    f for f in os.listdir(output_dir) 
    if os.path.isfile(os.path.join(output_dir, f))
]

# Filtra i file con estensione .hdf5
hdf5_files = [f for f in files if f.endswith(".hdf5")]

# Rimuovi ciascun file HDF5
for hdf5_file in hdf5_files:
    file_path = os.path.join(output_dir, hdf5_file)
    os.remove(file_path)
    print(f"File {hdf5_file} rimosso con successo.")
# Out:
# File single_1.hdf5 rimosso con successo.
# File single_10.hdf5 rimosso con successo.
# File single_100.hdf5 rimosso con successo.
# File single_11.hdf5 rimosso con successo.
# File single_12.hdf5 rimosso con successo.
# File single_13.hdf5 rimosso con successo.
# File single_14.hdf5 rimosso con successo.
# File single_15.hdf5 rimosso con successo.
# File single_16.hdf5 rimosso con successo.
# File single_17.hdf5 rimosso con successo.
# File single_18.hdf5 rimosso con successo.
# File single_19.hdf5 rimosso con successo.
# File single_2.hdf5 rimosso con successo.
# File single_20.hdf5 rimosso con successo.
# File single_21.hdf5 rimosso con successo.
# File single_22.hdf5 rimosso con successo.
# File single_23.hdf5 rimosso con successo.
# File single_24.hdf5 rimosso con successo.
# File single_25.hdf5 rimosso con successo.
# File single_26.hdf5 rimosso con successo.
# File single_27.hdf5 rimosso con successo.
# File single_28.hdf5 rimosso con successo.
# File single_29.hdf5 rimosso con successo.
# File single_3.hdf5 rimosso con successo.
# File single_30.hdf5 rimosso con successo.
# File single_31.hdf5 rimosso con successo.
# File single_32.hdf5 rimosso con successo.
# File single_33.hdf5 rimosso con successo.
# File single_34.hdf5 rimosso con successo.
# File single_35.hdf5 rimosso con successo.
# File single_36.hdf5 rimosso con successo.
# File single_37.hdf5 rimosso con successo.
# File single_38.hdf5 rimosso con successo.
# File single_39.hdf5 rimosso con successo.
# File single_4.hdf5 rimosso con successo.
# File single_40.hdf5 rimosso con successo.
# File single_41.hdf5 rimosso con successo.
# File single_42.hdf5 rimosso con successo.
# File single_43.hdf5 rimosso con successo.
# File single_44.hdf5 rimosso con successo.
# File single_45.hdf5 rimosso con successo.
# File single_46.hdf5 rimosso con successo.
# File single_47.hdf5 rimosso con successo.
# File single_48.hdf5 rimosso con successo.
# File single_49.hdf5 rimosso con successo.
# File single_5.hdf5 rimosso con successo.
# File single_50.hdf5 rimosso con successo.
# File single_51.hdf5 rimosso con successo.
# File single_52.hdf5 rimosso con successo.
# File single_53.hdf5 rimosso con successo.
# File single_54.hdf5 rimosso con successo.
# File single_55.hdf5 rimosso con successo.
# File single_56.hdf5 rimosso con successo.
# File single_57.hdf5 rimosso con successo.
# File single_58.hdf5 rimosso con successo.
# File single_59.hdf5 rimosso con successo.
# File single_6.hdf5 rimosso con successo.
# File single_60.hdf5 rimosso con successo.
# File single_61.hdf5 rimosso con successo.
# File single_62.hdf5 rimosso con successo.
# File single_63.hdf5 rimosso con successo.
# File single_64.hdf5 rimosso con successo.
# File single_65.hdf5 rimosso con successo.
# File single_66.hdf5 rimosso con successo.
# File single_67.hdf5 rimosso con successo.
# File single_68.hdf5 rimosso con successo.
# File single_69.hdf5 rimosso con successo.
# File single_7.hdf5 rimosso con successo.
# File single_70.hdf5 rimosso con successo.
# File single_71.hdf5 rimosso con successo.
# File single_72.hdf5 rimosso con successo.
# File single_73.hdf5 rimosso con successo.
# File single_74.hdf5 rimosso con successo.
# File single_75.hdf5 rimosso con successo.
# File single_76.hdf5 rimosso con successo.
# File single_77.hdf5 rimosso con successo.
# File single_78.hdf5 rimosso con successo.
# File single_79.hdf5 rimosso con successo.
# File single_8.hdf5 rimosso con successo.
# File single_80.hdf5 rimosso con successo.
# File single_81.hdf5 rimosso con successo.
# File single_82.hdf5 rimosso con successo.
# File single_83.hdf5 rimosso con successo.
# File single_84.hdf5 rimosso con successo.
# File single_85.hdf5 rimosso con successo.
# File single_86.hdf5 rimosso con successo.
# File single_87.hdf5 rimosso con successo.
# File single_88.hdf5 rimosso con successo.
# File single_89.hdf5 rimosso con successo.
# File single_9.hdf5 rimosso con successo.
# File single_90.hdf5 rimosso con successo.
# File single_91.hdf5 rimosso con successo.
# File single_92.hdf5 rimosso con successo.
# File single_93.hdf5 rimosso con successo.
# File single_94.hdf5 rimosso con successo.
# File single_95.hdf5 rimosso con successo.
# File single_96.hdf5 rimosso con successo.
# File single_97.hdf5 rimosso con successo.
# File single_98.hdf5 rimosso con successo.
# File single_99.hdf5 rimosso con successo.

# %% [markdown]
# # Save links list

# %%
# - Create google sheet
# - Open google scripts and paste:

# function myFunction() {
#   var ss=SpreadsheetApp.getActiveSpreadsheet();
#   var s=ss.getActiveSheet();
#   var c=s.getActiveCell();
#   var fldr=DriveApp.getFolderById("1GjOOJKpWZjl_IB0EWZueF9IVM9aT_WHW"); #<- Root folder ID
#   var files=fldr.getFiles();
#   var names=[],f,str;
#   while (files.hasNext()) {
#     f=files.next();
#     str='("' + f.getUrl() + '","' + f.getName() + '")';
#     names.push([str]);
#   }
#   s.getRange(c.getRow(),c.getColumn(),names.length).setValues(names);
# }

# %%
#from: https://drive.google.com/file/d/1_tjLpicJtQEAz43jhYMeE3TF4-WNxFVw/view?usp=drive_link
#to: https://drive.google.com/uc?export=download&id=1_tjLpicJtQEAz43jhYMeE3TF4-WNxFVw

# %%
old_links = defaultdict(int)

with open(tsv_path, 'r', encoding = 'utf-  8') as file_tsv:
    # Leggi ogni riga del file
    for riga in file_tsv:
        # Rimuovi eventuali spazi bianchi all'inizio e alla fine della riga
        riga = riga.strip()

        # Dividi la riga in colonne usando il separatore di tabulazione
        column = riga.split('\t')[0]
        splitted_column = column.strip("()").split(",")
        link = splitted_column[0]
        filename = splitted_column[1]
        old_links[filename] = link

chiavi_da_elimare = [
    chiave for chiave, 
    valore in old_links.items() if ".zip" not in chiave
]

# Elimina le chiavi che non rispettano la condizione
for chiave in chiavi_da_elimare:
    del old_links[chiave]

old_links = defaultdict(
    int, 
    sorted(old_links.items(), 
    key = lambda x: int(x[0].split('_')[1].split('.')[0]))
)

old_links
# Out:
# defaultdict(int,
#             {'"bif_1.zip"': '"https://drive.google.com/file/d/1o1e_Vl3ub3fprAPjoMYh4K-rXWkmjM5t/view?usp=drivesdk"',
#              '"bif_2.zip"': '"https://drive.google.com/file/d/1b7ns8iKaTZUJrY6kxYqZyHQL6kajzeRR/view?usp=drivesdk"',
#              '"bif_3.zip"': '"https://drive.google.com/file/d/1mPRiznvvI_PYZG2yXDt-GLDzc2bqDbDw/view?usp=drivesdk"',
#              '"bif_4.zip"': '"https://drive.google.com/file/d/1Hn-dO8vc-a1RnUgkZ5kijbrcKjdDeUzX/view?usp=drivesdk"',
#              '"bif_5.zip"': '"https://drive.google.com/file/d/1CnK0VtdO191eww2C1_c8B44IjLAErPk8/view?usp=drivesdk"',
#              '"bif_6.zip"': '"https://drive.google.com/file/d/1WzLcQwSpSc0ntmYJ09sBRby9jQ1nMQ3d/view?usp=drivesdk"',
#              '"bif_7.zip"': '"https://drive.google.com/file/d/1-OWiVkSLX7B15YHS_8w_RzHuGtCLJQGq/view?usp=drivesdk"',
#              '"bif_8.zip"': '"https://drive.google.com/file/d/1zTXVy5lOY-HjDMQXuO8ANynEH_cwSkUC/view?usp=drivesdk"',
#              '"bif_9.zip"': '"https://drive.google.com/file/d/1IBMZhnetwRe27x0sPX_R1p-dgjGYEoYW/view?usp=drivesdk"',
#              '"bif_10.zip"': '"https://drive.google.com/file/d/1IFJRPVn-v5cXYGle70J5ru96ifanYCUt/view?usp=drivesdk"',
#              '"bif_11.zip"': '"https://drive.google.com/file/d/1a8ePXP5jYlAeCRYqQMTYUuEf-qBRCbZ1/view?usp=drivesdk"',
#              '"bif_12.zip"': '"https://drive.google.com/file/d/1XKfDi4idOQc6APD1L1ms5-smA_W5LQfQ/view?usp=drivesdk"',
#              '"bif_13.zip"': '"https://drive.google.com/file/d/13aldUlfeEXovU1vgPxtgZwILEV23hTPt/view?usp=drivesdk"',
#              '"bif_14.zip"': '"https://drive.google.com/file/d/14n3UzL62e3oYu784AKKPf14kKN6fRe0E/view?usp=drivesdk"',
#              '"bif_15.zip"': '"https://drive.google.com/file/d/16TGw0-yElzrYd41jdcrS6Pw8Ge8QIg9O/view?usp=drivesdk"',
#              '"bif_16.zip"': '"https://drive.google.com/file/d/1bKtihTzECz5N9zhSg_SaS54yfjgok5R6/view?usp=drivesdk"',
#              '"bif_99.zip"': '"https://drive.google.com/file/d/1whcIN0lpeUsB7nmoKZ4rkywo4YPJngTu/view?usp=drivesdk"',
#              '"bif_100.zip"': '"https://drive.google.com/file/d/1Dx335rjd2HjtMpOl_2xgfyaqzj16hBV2/view?usp=drivesdk"'})

# %%
final_links = []

for _,link in old_links.items():
        splitted_link = list(
            filter(
                lambda x: x != '', 
                link.strip().split("/")
             )
         )
        file_id = splitted_link[-2]
        prefix = splitted_link[:2]
        command = "/uc?export=download&id="+file_id
        header = prefix[0][1:] + "//" + prefix[1]
        final_link = "".join(header + command)
        final_links.append(final_link)

len(final_links)
# Out:
# 100

# %%
# Salva la lista come file pickle
with open(links_path.replace(".txt",".pkl"), 'wb') as file_pkl:
    pkl.dump(final_links, file_pkl)

# %%
with open(links_path.replace(".txt",".pkl"), 'rb') as file_pkl:
    fff = pkl.load(file_pkl)
    print(fff)
# Out:
# ['https://drive.google.com/uc?export=download&id=1o1e_Vl3ub3fprAPjoMYh4K-rXWkmjM5t', 'https://drive.google.com/uc?export=download&id=1b7ns8iKaTZUJrY6kxYqZyHQL6kajzeRR', 'https://drive.google.com/uc?export=download&id=1mPRiznvvI_PYZG2yXDt-GLDzc2bqDbDw', 'https://drive.google.com/uc?export=download&id=1Hn-dO8vc-a1RnUgkZ5kijbrcKjdDeUzX', 'https://drive.google.com/uc?export=download&id=1CnK0VtdO191eww2C1_c8B44IjLAErPk8', 'https://drive.google.com/uc?export=download&id=1WzLcQwSpSc0ntmYJ09sBRby9jQ1nMQ3d', 'https://drive.google.com/uc?export=download&id=1-OWiVkSLX7B15YHS_8w_RzHuGtCLJQGq', 'https://drive.google.com/uc?export=download&id=1zTXVy5lOY-HjDMQXuO8ANynEH_cwSkUC', 'https://drive.google.com/uc?export=download&id=1IBMZhnetwRe27x0sPX_R1p-dgjGYEoYW', 'https://drive.google.com/uc?export=download&id=1IFJRPVn-v5cXYGle70J5ru96ifanYCUt', 'https://drive.google.com/uc?export=download&id=1a8ePXP5jYlAeCRYqQMTYUuEf-qBRCbZ1', 'https://drive.google.com/uc?export=download&id=1XKfDi4idOQc6APD1L1ms5-smA_W5LQfQ', 'https://drive.google.com/uc?export=download&id=13aldUlfeEXovU1vgPxtgZwILEV23hTPt', 'https://drive.google.com/uc?export=download&id=14n3UzL62e3oYu784AKKPf14kKN6fRe0E', 'https://drive.google.com/uc?export=download&id=16TGw0-yElzrYd41jdcrS6Pw8Ge8QIg9O', 'https://drive.google.com/uc?export=download&id=1bKtihTzECz5N9zhSg_SaS54yfjgok5R6', 'https://drive.google.com/uc?export=download&id=1WzFFZ9l0mKccfH07GE37eCi0g3ONWJc3', 'https://drive.google.com/uc?export=download&id=1w_YzbVKdKkJbpaYY3ReSxf-jNe7AVw85', 'https://drive.google.com/uc?export=download&id=1w6FaF0B4U5rSxnM5yndsTObulOUpF5kj', 'https://drive.google